# %% [markdown]
# # Event explorer
# Add description here

# %%
from matplotlib import pyplot as plt
import sys
sys.path.append(r"C:\Users\trotta\Desktop\Shocks\ShockWatcher\solo_swa_loader")
from solo_mag_loader import mag_load
from solo_epd_loader import epd_load
from solo_swa_loader import swa_load_grnd_mom
import datetime as dt
import numpy as np
import pandas as pd
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter, AutoMinorLocator)
import matplotlib.dates as mdates
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [14], in <cell line: 6>()
#       4 from solo_mag_loader import mag_load
#       5 from solo_epd_loader import epd_load
# ----> 6 from solo_swa_loader import swa_load_grnd_mom
#       7 import datetime as dt
#       8 import numpy as np
#
# ModuleNotFoundError: No module named 'solo_swa_loader'
